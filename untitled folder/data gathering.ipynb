# %%
import requests
import http.client
import pandas as pd
from pprint import pprint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os

# %% [markdown]
# export SPOTIPY_CLIENT_ID='your-spotify-client-id'
# export SPOTIPY_CLIENT_SECRET='your-spotify-client-secret'
# export SPOTIPY_REDIRECT_URI='your-app-redirect-url'

# %%
SPOTIPY_CLIENT_ID = '2ea0f380d0794b2a9d705ac2b9feac6a'
SPOTIPY_CLIENT_SECRET = 'c80f9cc3dc2443fbb458ee7f428535c7'

os.environ['SPOTIPY_CLIENT_SECRET'] = SPOTIPY_CLIENT_SECRET
os.environ['SPOTIPY_CLIENT_ID'] = SPOTIPY_CLIENT_ID

# client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)

# %%
birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Young Heart
# Beautiful Lies
# Beautiful Lies
# Beautiful Lies (Deluxe)
# Beautiful Lies (Deluxe)
# Fire Within
# Fire Within
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Live in London
# Birdy
# Birdy
# Birdy
# Birdy
# Birdy (Deluxe Version)

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
categories = spotify.categories()

# %%
print(categories)
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?offset=0&limit=20', 'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists', 'icons': [{'height': 275, 'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg', 'width': 275}], 'id': 'toplists', 'name': 'Top Lists'}, {'href': 'https://api.spotify.com/v1/browse/categories/at_home', 'icons': [{'height': None, 'url': 'https://t.scdn.co/images/04da469dd7be4dab96659aa1fa9f0ac9.jpeg', 'width': None}], 'id': 'at_home', 'name': 'At Home'}, {'href': 'https://api.spotify.com/v1/browse/categories/pop', 'icons': [{'height': 274, 'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg', 'width': 274}], 'id': 'pop', 'name': 'Pop'}, {'href': 'https://api.spotify.com/v1/browse/categories/equal', 'icons': [{'height': None, 'url': 'https://t.scdn.co/images/084155aeaa724ea1bd393a017d67b709', 'width': None}], 'id': 'equal', 'name'
# ...

# %%
keys = []
values = []
items = categories.items()
for item in items:
    keys.append(item[0]), values.append(item[1])

# %%
auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
#    1 spotify:playlist:37i9dQZF1DXcBWIGoYBM5M Today's Top Hits
#    2 spotify:playlist:37i9dQZF1DX0XUsuxWHRQd RapCaviar
#    3 spotify:playlist:37i9dQZF1DX1lVhptIYRda Hot Country
#    4 spotify:playlist:37i9dQZF1DX10zKzsJ2jva ¡Viva Latino!
#    5 spotify:playlist:37i9dQZF1DX4JAvHpjipBk New Music Friday
#    6 spotify:playlist:37i9dQZF1DX4sWSpwq3LiO Peaceful Piano
#    7 spotify:playlist:37i9dQZF1DX4SBhb3fqCJd Are & Be
#    8 spotify:playlist:37i9dQZF1DWXRqgorJj26U Rock Classics
#    9 spotify:playlist:37i9dQZF1DX4dyzvuaRJ0n mint
#   10 spotify:playlist:37i9dQZF1DXcF6B6QPhFDv Rock This
#   11 spotify:playlist:37i9dQZF1DWXJfnUiYjUKT New Music Friday
#   12 spotify:playlist:37i9dQZF1DXcRXFNfZr7Tp just hits
#   13 spotify:playlist:37i9dQZF1DX4o1oenSJRJd All Out 00s
#   14 spotify:playlist:37i9dQZF1DXbTxeAdrVG2l All Out 90s
#   15 spotify:playlist:37i9dQZF1DX4UtSsGT1Sbe All Out 80s
#   16 spotify:playlist:37i9dQZF1DWTJ7xPn4vNaz All Out 70s
# ...

# %%
categories = sp.categories(country="US")['categories']


print(categories)
# Out:
# {'href': 'https://api.spotify.com/v1/browse/categories?country=US&offset=0&limit=20', 'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists', 'icons': [{'height': 275, 'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg', 'width': 275}], 'id': 'toplists', 'name': 'Top Lists'}, {'href': 'https://api.spotify.com/v1/browse/categories/hiphop', 'icons': [{'height': 274, 'url': 'https://t.scdn.co/media/original/hip-274_0a661854d61e29eace5fe63f73495e68_274x274.jpg', 'width': 274}], 'id': 'hiphop', 'name': 'Hip Hop'}, {'href': 'https://api.spotify.com/v1/browse/categories/pop', 'icons': [{'height': 274, 'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg', 'width': 274}], 'id': 'pop', 'name': 'Pop'}, {'href': 'https://api.spotify.com/v1/browse/categories/country', 'icons': [{'height': None, 'url': 'https://t.scdn.co/images/a2e0ebe2ebed4566ba1d8236b869241f.jpeg', 'width': None}],
# ...

# %%
keys = categories.keys()

print(keys)
keys1 = []
for k in keys:
    keys1.append(k)
print(keys1)
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']

# %%
values = categories.values()
values = list(values)
# values = pd.DataFrame(values)
values.pop(0)
print(values)
# Out:
# [[{'href': 'https://api.spotify.com/v1/browse/categories/toplists', 'icons': [{'height': 275, 'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg', 'width': 275}], 'id': 'toplists', 'name': 'Top Lists'}, {'href': 'https://api.spotify.com/v1/browse/categories/hiphop', 'icons': [{'height': 274, 'url': 'https://t.scdn.co/media/original/hip-274_0a661854d61e29eace5fe63f73495e68_274x274.jpg', 'width': 274}], 'id': 'hiphop', 'name': 'Hip Hop'}, {'href': 'https://api.spotify.com/v1/browse/categories/pop', 'icons': [{'height': 274, 'url': 'https://t.scdn.co/media/derived/pop-274x274_447148649685019f5e2a03a39e78ba52_0_0_274_274.jpg', 'width': 274}], 'id': 'pop', 'name': 'Pop'}, {'href': 'https://api.spotify.com/v1/browse/categories/country', 'icons': [{'height': None, 'url': 'https://t.scdn.co/images/a2e0ebe2ebed4566ba1d8236b869241f.jpeg', 'width': None}], 'id': 'country', 'name': 'Country'}, {'href': 'https://api.spotify.com/v1/browse/categories/r
# ...

# %%
cate = []
for v in values:
#     for x in v:
        y = str(x['id'])
        print(y)
        cate.append(str(y))
        
# type(y)
# Out:
# kids_family
# kids_family
# kids_family
# kids_family
# kids_family
# kids_family

# %%
print(cate)
# Out:
# ['toplists', 'hiphop', 'pop', 'country', 'rock', 'latin', 'mood', 'aapi_heritage_month', 'rnb', 'workout', 'edm_dance', 'indie_alt', 'sleep', 'chill', 'inspirational', 'equal', 'focus', 'decades', 'party', 'kids_family']

# %%
cate = ['country','edm_dance','hiphop', 'pop','latin']

# %%
cat=[]
cate_info={}
for c in cate:
    cate_info[c] = sp.category_playlists(c,country='US',limit=50, offset=0)
    pprint(cate_info)  
#     cat.append(cate_info[c])
# Out:
# {'country': {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/country/playlists?country=US&offset=0&limit=50',
#                            'items': [{'collaborative': False,
#                                       'description': "Today's top country hits "
#                                                      'of the week, worldwide! '
#                                                      'Cover: Thomas Rhett',
#                                       'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1lVhptIYRda'},
#                                       'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda',
#                                       'id': '37i9dQZF1DX1lVhptIYRda',
#                                       'images': [{'height': None,
#                                                   'url': 'https://i.scdn.co/image/ab67706f0000000381a05cd9b64ce21d3177b6ee',
# ...

# %%
cate_info.keys()
# Out:
# dict_keys(['country', 'edm_dance', 'hiphop', 'pop', 'latin'])

# %%
cate_info.values()
# Out:
# dict_values([{'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/country/playlists?country=US&offset=0&limit=50', 'items': [{'collaborative': False, 'description': "Today's top country hits of the week, worldwide! Cover: Thomas Rhett", 'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1lVhptIYRda'}, 'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda', 'id': '37i9dQZF1DX1lVhptIYRda', 'images': [{'height': None, 'url': 'https://i.scdn.co/image/ab67706f0000000381a05cd9b64ce21d3177b6ee', 'width': None}], 'name': 'Hot Country', 'owner': {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}, 'primary_color': None, 'public': None, 'snapshot_id': 'MTYxOTgwNzAzNiwwMDAwMDMwZTAwMDAwMTc5MjQwNWUyYjEwMDAwMDE3OTFiNWI2OTdl', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/3
# ...

# %%
# total_list = []
# for item in cate_info1:
# #     pprint(item)
# #     for c in item:
#         cur_dict = {'category': 'Latin'}
#         cur_dict['description'] = item['description']
#         cur_dict['name'] = item['name']
#         cur_dict['uri']= item['uri']
#         cur_dict['tracks'] = item['tracks']
#         cur_dict['url'] = item['external_urls']
#         total_list.append(cur_dict)

# %%
print(cate_info)
# Out:
# {'country': {'playlists': {'href': 'https://api.spotify.com/v1/browse/categories/country/playlists?country=US&offset=0&limit=50', 'items': [{'collaborative': False, 'description': "Today's top country hits of the week, worldwide! Cover: Thomas Rhett", 'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1lVhptIYRda'}, 'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda', 'id': '37i9dQZF1DX1lVhptIYRda', 'images': [{'height': None, 'url': 'https://i.scdn.co/image/ab67706f0000000381a05cd9b64ce21d3177b6ee', 'width': None}], 'name': 'Hot Country', 'owner': {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}, 'primary_color': None, 'public': None, 'snapshot_id': 'MTYxOTgwNzAzNiwwMDAwMDMwZTAwMDAwMTc5MjQwNWUyYjEwMDAwMDE3OTFiNWI2OTdl', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/37
# ...

# %%
cleaner = cate_info['country']['playlists']
print(cleaner)
# Out:
# {'href': 'https://api.spotify.com/v1/browse/categories/country/playlists?country=US&offset=0&limit=50', 'items': [{'collaborative': False, 'description': "Today's top country hits of the week, worldwide! Cover: Thomas Rhett", 'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1lVhptIYRda'}, 'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda', 'id': '37i9dQZF1DX1lVhptIYRda', 'images': [{'height': None, 'url': 'https://i.scdn.co/image/ab67706f0000000381a05cd9b64ce21d3177b6ee', 'width': None}], 'name': 'Hot Country', 'owner': {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}, 'primary_color': None, 'public': None, 'snapshot_id': 'MTYxOTgwNzAzNiwwMDAwMDMwZTAwMDAwMTc5MjQwNWUyYjEwMDAwMDE3OTFiNWI2OTdl', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda/track
# ...

# %%
for c in cate_info.keys():
    urls = [x['external_urls']['spotify'] for x in sp.category_playlists(c,country='US',limit=50, offset=0)['playlists']['items']]
    cate_info[c] = urls
    
print(urls)
# Out:
# ['https://open.spotify.com/playlist/37i9dQZF1DX10zKzsJ2jva', 'https://open.spotify.com/playlist/37i9dQZF1DWY7IeIP1cdjF', 'https://open.spotify.com/playlist/37i9dQZF1DX1hVRardJ30X', 'https://open.spotify.com/playlist/37i9dQZF1DX4OjfOteYnH8', 'https://open.spotify.com/playlist/37i9dQZF1DX2MJVTOdWtbm', 'https://open.spotify.com/playlist/37i9dQZF1DWZoF06RIo9el', 'https://open.spotify.com/playlist/37i9dQZF1DWYzQ2Vx5M6uV', 'https://open.spotify.com/playlist/37i9dQZF1DX5AVYhCeISA6', 'https://open.spotify.com/playlist/37i9dQZF1DXbSwbJpH6lAw', 'https://open.spotify.com/playlist/37i9dQZF1DXagUeYbNSnOA', 'https://open.spotify.com/playlist/37i9dQZF1DXbdrcAZnP3Cy', 'https://open.spotify.com/playlist/37i9dQZF1DX1QnNyJOBQBv', 'https://open.spotify.com/playlist/37i9dQZF1DX4oUPBOaEkL6', 'https://open.spotify.com/playlist/37i9dQZF1DX1ziQH0F90kL', 'https://open.spotify.com/playlist/37i9dQZF1DX07RJCJCOYpi', 'https://open.spotify.com/playlist/37i9dQZF1DX4V5eXk4NKqu', 'https://open.spotify.com/playlist/37
# ...

# %%
cate_info = {'country':[],'edm_dance':[],'hiphop':[], 'pop':[],'latin':[]}
for c in cate_info.keys():
    uris = [x['uri'] for x in sp.category_playlists(c,country='US',limit=50, offset=0)['playlists']['items']]
    cate_info[c] = uris
    
print(uris)
# Out:
# ['spotify:playlist:37i9dQZF1DX10zKzsJ2jva', 'spotify:playlist:37i9dQZF1DWY7IeIP1cdjF', 'spotify:playlist:37i9dQZF1DX1hVRardJ30X', 'spotify:playlist:37i9dQZF1DX4OjfOteYnH8', 'spotify:playlist:37i9dQZF1DX2MJVTOdWtbm', 'spotify:playlist:37i9dQZF1DWZoF06RIo9el', 'spotify:playlist:37i9dQZF1DWYzQ2Vx5M6uV', 'spotify:playlist:37i9dQZF1DX5AVYhCeISA6', 'spotify:playlist:37i9dQZF1DXbSwbJpH6lAw', 'spotify:playlist:37i9dQZF1DXagUeYbNSnOA', 'spotify:playlist:37i9dQZF1DXbdrcAZnP3Cy', 'spotify:playlist:37i9dQZF1DX1QnNyJOBQBv', 'spotify:playlist:37i9dQZF1DX4oUPBOaEkL6', 'spotify:playlist:37i9dQZF1DX1ziQH0F90kL', 'spotify:playlist:37i9dQZF1DX07RJCJCOYpi', 'spotify:playlist:37i9dQZF1DX4V5eXk4NKqu', 'spotify:playlist:37i9dQZF1DX4qKWGR9z0LI', 'spotify:playlist:37i9dQZF1DXbgLhPxSBEKX', 'spotify:playlist:37i9dQZF1DX7Qo2zphj7u3', 'spotify:playlist:37i9dQZF1DX5U9LWxuimGj', 'spotify:playlist:37i9dQZF1DX2lenzaqw2vs', 'spotify:playlist:37i9dQZF1DWSDautEwAKZB', 'spotify:playlist:37i9dQZF1DXbUMEWUyV9JB', 'spotify
# ...

# %%
playlist_tracks = []
for uri in uris:
    tracks1 = sp.playlist_tracks(playlist_id = uri, limit= 100)
#     pprint(tracks1)
    playlist_tracks.append(tracks1['total'])

# %%
for c in cate_info.keys():
    names = [x['name'] for x in sp.category_playlists(c,country='US',limit=50, offset=0)['playlists']['items']]
    cate_info[c] = names
    
print(names)
# Out:
# ['¡Viva Latino!', 'Baila Reggaeton', 'New Music Friday Latin', 'Urbano Rising', 'Are & Be Latin', 'Future Hits: Latin', 'Afro Ritmo', 'Inspiring Latinas', 'Radar US Latin', 'Fresh Finds: Latin', 'Mexican Party Anthems', 'Latin Pop Hits', 'Éxitos USA', 'Now & Then Reggaeton', 'mint Latin', 'Ultimate LatinX Indie', 'Salsa Nation', 'Grandes Voces', 'Hits Románticos', 'Country Latino', 'Latin Pride', 'Spotify Singles: Latino', 'Super Cumbias', 'Latin Hit Mix', 'Fuego', 'Reggaeton Classics', 'Puro Perreo', 'Bachata Classics', 'Cumbia Sonidera', 'Fiesta', 'internet crush', 'Rock en Español', 'Salsa Classics', 'Latin Pop Classics', 'Latin Party Anthems', 'Perrear y Llorar', '100% Cumbia', 'Remixes Urbanos', 'Viral Latino', 'Latin Cardio', 'Esenciales', 'Canciones del Recuerdo', '90s Latino', '10s Latino', 'Mal de Amores', 'Cleaning Kit en Español', 'This Is J Balvin', 'Trap Classics', 'Latin Drive', 'New Urbano']

# %%
print(playlist_tracks)
# Out:
# [50, 50, 65, 55, 85, 50, 54, 75, 30, 50, 90, 50, 50, 90, 58, 100, 150, 50, 250, 49, 82, 26, 50, 100, 55, 100, 100, 50, 50, 106, 75, 60, 90, 100, 125, 86, 50, 74, 50, 100, 150, 150, 75, 85, 50, 80, 95, 55, 120, 56]

# %%
df_dict = {
    'name': names,
    'playlist_tracks': playlist_tracks,
    'uri': uris,
    'url': urls,
}
df5 = pd.DataFrame(df_dict)

# %%
df5.head()
# Out:
#                      name  playlist_tracks  \
# 0           ¡Viva Latino!               50
# 1         Baila Reggaeton               50
# 2  New Music Friday Latin               65
# 3           Urbano Rising               55
# 4          Are & Be Latin               85
#
#                                        uri  \
# 0  spotify:playlist:37i9dQZF1DX10zKzsJ2jva
# 1  spotify:playlist:37i9dQZF1DWY7IeIP1cdjF
# 2  spotify:playlist:37i9dQZF1DX1hVRardJ30X
# 3  spotify:playlist:37i9dQZF1DX4OjfOteYnH8
# 4  spotify:playlist:37i9dQZF1DX2MJVTOdWtbm
#
#                                                  url
# 0  https://open.spotify.com/playlist/37i9dQZF1DX1...
# 1  https://open.spotify.com/playlist/37i9dQZF1DWY...
# 2  https://open.spotify.com/playlist/37i9dQZF1DX1...
# 3  https://open.spotify.com/playlist/37i9dQZF1DX4...
# 4  https://open.spotify.com/playlist/37i9dQZF1DX2...

# %%
df5.to_csv('latin.csv')
